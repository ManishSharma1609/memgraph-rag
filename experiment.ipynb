# %%
import pickle
# Load the graph_documents from the pickle file
with open('graph_documents.pkl', 'rb') as f:
    graph_documents = pickle.load(f)

# %%
print(f"Nodes:{graph_documents[1].nodes}")
print(f"Nodes:{graph_documents[1].relationships}")
# Out:
# Nodes:[Node(id='Po9909', type='Purchase order', properties={}), Node(id='C.H. Robinson', type='Supplier', properties={}), Node(id='Ltl', type='Service', properties={}), Node(id='Transportation Service', type='Service category', properties={}), Node(id='Ground Freight', type='Service category', properties={}), Node(id='Cat5665', type='Catalog', properties={}), Node(id='Ohio', type='Location', properties={}), Node(id='Brampton', type='Location', properties={}), Node(id='Foseco Manufacturing', type='Location', properties={}), Node(id='Easeworkai', type='Location', properties={}), Node(id='Ratha Natarajanan', type='Person', properties={}), Node(id='Jose Tran', type='Person', properties={})]
# ...

# %%
for i in range(len(graph_documents)):
    print(i)
    print(f"Nodes:{graph_documents[i].nodes}")
    print(f"Nodes:{graph_documents[i].relationships}")
    
    print("\n")
# Out:
# 0
# Nodes:[Node(id='Po9902', type='Purchase order', properties={}), Node(id='C.H. Robinson', type='Supplier', properties={}), Node(id='Ltl', type='Service', properties={}), Node(id='Transportation Service', type='Service category', properties={}), Node(id='Ground Freight', type='Service category', properties={}), Node(id='Cat5665', type='Catalog', properties={}), Node(id='Ohio', type='Location', properties={}), Node(id='Brampton', type='Location', properties={}), Node(id='Jose Tran', type='Person', properties={}), Node(id='Foseco Manufacturing', type='Location', properties={}), Node(id='Easeworkai', type='Location', properties={}), Node(id='Ratha Natarajanan', type='Person', properties={})]
# ...
